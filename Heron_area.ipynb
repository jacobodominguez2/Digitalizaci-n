# %% [markdown]
# <a href="https://colab.research.google.com/github/jacobodominguez2/Digitalizaci-n/blob/main/Heron_area.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cálculo del área de un triángulo
# Usando la fórmula de Herón, calculamos el área de cualquier triángulo conociendo la longitud de sus tres lados. Debes escribir un programa que te pida los tres lados y que calcule el área.
#
#
# > Cálculo del semiperímetro: $s = \frac{a+b+c}{2}$
#
# > Cálculo del área: $área = \sqrt{s(s-a)(s-b)(s-c)}$

# %%
#Pedimos el valor entero de cada uno de los lados
ladoA = int(input("Dime el lado A: "))
ladoB = int(input("Dime el lado B: "))
ladoC = int(input("Dime el lado C: "))

#Cálculo del semiperímetro
s= (ladoA+ladoB+ladoC)/2
#Cálculo del área
area=(s*(s-ladoA)*(s-ladoB)*(s-ladoC))**0.5
#Imprimimos el resultado
print(area)
# Out:
# Dime el lado A: 8
# Dime el lado B: 10
# Dime el lado C: 12
# 39.68626966596886
